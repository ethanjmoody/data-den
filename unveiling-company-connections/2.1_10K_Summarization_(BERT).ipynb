# %% [markdown]
# <font color='#E27271'>
#
# # *Unveiling Complex Interconnections Among Companies through Learned Embeddings*</font>
#
# -----------------------
# <font color='#E27271'>
#
# Ethan Moody, Eugene Oon, and Sam Shinde</font>
#
# <font color='#E27271'>
#
# August 2023</font>

# %% [markdown]
# -----------------------
# <font color='#00AED3'>
#
# # **BERT Summarization** </font>
# -----------------------
#
# BERT Summarization refers to the application of the Bidirectional Encoder Representations from Transformers (BERT) model for automatic text summarization. BERT, a powerful language representation model, is pre-trained on vast amounts of text data, enabling it to capture context and semantics effectively. In the context of summarization, BERT is fine-tuned on large datasets with source text and corresponding summaries to learn to generate concise and coherent summaries that capture the most important information from the original text.
#
# We leverage the power of BERT to summarize 10K `business` section of varied length from various companies to standard 25 sentences (approx 512 tokens) which will be used in our downstream classification task.

# %% [markdown]
# # [1] Installs

# %%
# !pip install transformers --quiet
# !pip install bert-extractive-summarizer --quiet
# !pip install spacy --quiet
# !python -m spacy download en_core_web_lg --quiet
# !pip install sentencepiece --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 50.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 24.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 82.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 60.3 MB/s eta 0:00:00
# 2023-07-30 17:30:47.014132: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-30 17:30:48.049214: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-07-30 17:30:49.426675: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-30 17:30:49.427170: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-30 17:30:49.427350: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.7/587.7 MB 2.4 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 18.2 MB/s eta 0:00:00

# %% [markdown]
# # [2] Imports

# %%
# Imports General Packages
import os, sys
import pandas as pd
import json
from datetime import date
import re
from datetime import datetime

#
import jax
from jax import numpy as jnp

# Import Transformers
from transformers import BertTokenizer, TFBertModel, BertConfig
import tensorflow as tf

import spacy
from spacy import displacy
nlp = spacy.load('en_core_web_lg')

# Setup
path = '/content/gdrive/My Drive/project'
working_path = '/content/gdrive/My Drive/Working'

# Summarizer
from summarizer import Summarizer,TransformerSummarizer

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # [3] Mount GDrive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # [4] Read Input Files

# %%
sp_df = pd.read_json(path + '/data/10K/sp500_final.json')
nsp_df = pd.read_json(path + '/data/10K/nsp500_final.json')

# %%
# Non S&P Cleanup
nsp_df = nsp_df.sort_values(by=['ticker','year','formType'], ignore_index=True)
nsp_df.head()
print(f'Starting Data                       : {nsp_df.shape[0]}')

nsp_df = nsp_df.drop_duplicates(subset = ['ticker', 'year'],keep = 'first').reset_index(drop = True)
print(f'After Dropping Duplicates           : {nsp_df.shape[0]}')

nsp_df = nsp_df[nsp_df['sector'].notnull()]
nsp_df.reset_index(drop=True, inplace=True)
print(f'After Dropping Sector = None        : {nsp_df.shape[0]}')

nsp_df = nsp_df[nsp_df['business_cnt']!=0]
nsp_df.reset_index(drop=True, inplace=True)
print(f'After Dropping Business Count = 0   : {nsp_df.shape[0]}')

nsp_df = nsp_df[nsp_df['business_cnt']>=5000]
nsp_df.reset_index(drop=True, inplace=True)
print(f'After Dropping Business Count < 5000: {nsp_df.shape[0]}')

# %% [markdown]
# # [5] Helper Function (Clean Raw Texts)

# %%
def clean(rawtext):
  """Function to remove unwanted text which might impact model performance, such as -
      Remove Special Characters
      Remove Consecutive Whitespace
      Remove new line characters
      Remove Table Content
      Remove all characters except lowercase or uppercase alphabetic character
      (a-z, A-Z) or a whitespace character (\s) or dot (.)
  """

  # Remove specific (non-breaking space) character sequence
  rawtext = rawtext.replace('\\xa0','')

  # Remove New Line (escape the backslash)
  rawtext = rawtext.replace('\\n','')

  # pattern that matches one or more consecutive whitespace characters
  rawtext = re.sub('\s\s+',' ',rawtext)

  # Replace new line with Space
  rawtext = re.sub('\n',' ',rawtext)

  # Replace Table Content
  rawtext = re.sub("(?is)<table[^>]*>(.*?)<\/table>", "", rawtext)

  # pattern that matches any character that is not a lowercase or uppercase alphabetic character (a-z, A-Z) or a whitespace character (\s)
  rawtext = re.sub(r'[^A-Za-z .]+', '', rawtext)
  # rawtext = re.sub(r'[^A-Za-z0-9 .]+', '', rawtext)
  # rawtext = re.sub('[^a-zA-Z\s]','',rawtext)

  # pattern that matches one or more consecutive digits
  # rawtext = re.sub(r'\d+', '', rawtext)

  rawtext = re.sub('I tem','',rawtext)
  rawtext = re.sub('TABLEEND','',rawtext)
  rawtext = re.sub('TABLESTART','',rawtext)

  # matches one or more consecutive spaces
  rawtext = re.sub(' +', ' ', rawtext)

  return rawtext

# %% [markdown]
# # [6] Summarization

# %% [markdown]
# ## [6.1] BERT Summarizer

# %%
# BERT Models
BERT_model = Summarizer()
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]

# %%
#nsp_df.sort_values(by='business_cnt',ascending=False, inplace=True, ignore_index=True)
nsp_df = nsp_df[nsp_df['business_cnt']>0].sort_values(by='business_cnt',ascending=False, ignore_index=True)
sp_df = sp_df[sp_df['business_cnt']>0].sort_values(by='business_cnt',ascending=False, ignore_index=True)

# %% [markdown]
# ## [6.2] Run Summarization on Training Dataset

# %%
bert_nsp_summary = []
cnt = 1
ttlcnt = nsp_df[nsp_df['year']==2022].shape[0]
for index, row in nsp_df[nsp_df['year']==2022].iterrows():
  if row['business'][:5] != 'Error':
    business_summary = ''.join(BERT_model(clean(row['business'][0:100000]), min_length=20, num_sentences=25))
  else:
    business_summary = None
  result = {'ticker': row['ticker'],
            'cik': row['cik'],
            'formType': row['formType'],
            'filedAt': row['filedAt'],
            'linkToTxt': row['linkToTxt'],
            'linkToHtml': row['linkToHtml'],
            'periodOfReport': row['periodOfReport'],
            'year': row['year'],
            'ind': row['ind'],
            'name': row['name'],
            'sector': row['sector'],
            'industry': row['industry'],
            'industry_group': row['industry_group'],
            'business': business_summary}
  bert_nsp_summary.append(result)
  print('\b'*100, end = '')
  print(f'{cnt}/{ttlcnt}', end='')
  cnt+=1
# Out:
# 4057/4057

# %% [markdown]
# ## [6.3] Save Summarized Output (Training dataset)

# %%
# Write to detail file
file_path = path + '/data/10K/bert_nsp_summary_final.json'
with open(file_path, "w", encoding="utf-8") as file:
  json.dump(bert_nsp_summary, file, indent=4, separators=(',',': '))

# %% [markdown]
# ## [6.4] Run Summarization on Test Dataset

# %%
bert_sp_summary = []
cnt = 1
ttlcnt = sp_df.shape[0]
for index, row in sp_df[sp_df['year']==2022].iterrows():
  if row['business'][:5] != 'Error':
    business_summary = ''.join(BERT_model(clean(row['business'][0:1000000]), min_length=20, num_sentences=25))
  else:
    business_summary = None

  result = {'ticker': row['ticker'],
            'cik': row['cik'],
            'formType': row['formType'],
            'filedAt': row['filedAt'],
            'linkToTxt': row['linkToTxt'],
            'linkToHtml': row['linkToHtml'],
            'periodOfReport': row['periodOfReport'],
            'year': row['year'],
            'ind': row['ind'],
            'name': row['name'],
            'sector': row['sector'],
            'industry': row['industry'],
            'industry_group': row['industry_group'],
            'business': business_summary}
  bert_sp_summary.append(result)
  print('\b'*100, end = '')
  print(f'{cnt}/{ttlcnt}', end='')
  cnt+=1
# Out:
# 500/500

# %% [markdown]
# ## [6.5] Save Summarized Output (Test dataset)

# %%
# Write to detail file
file_path = path + '/data/10K/bert_sp_summary_final.json'
with open(file_path, "w", encoding="utf-8") as file:
  json.dump(bert_sp_summary, file, indent=4, separators=(',',': '))

# %% [markdown]
# ## [6.6] Delete Model

# %%
del BERT_model
